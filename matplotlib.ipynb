# %%
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
import numpy as np
import datetime as DT
import matplotlib.dates as mdates
from datetime import date
from matplotlib.pyplot import figure

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

def plot_country_cases(country_filter):
    df=pd.read_csv("https://opendata.ecdc.europa.eu/covid19/casedistribution/csv")

    d1 = df[(df['countriesAndTerritories'] == country_filter)]
   
    
    fig, ax = plt.subplots(1, 1)
    fig.set_size_inches(18.5, 10.5, forward=True)
    
    ax.plot(d1.dateRep, d1.cases)  
    
    ax.set_xticks(d1.dateRep[::5])
    plt.xticks(rotation=75,size=13)
    ax.invert_xaxis()
       
    plt.title(country_filter,size=20)
    ax.set_xlabel('Date',size=15)
    ax.set_ylabel('Number of Cases',size=15)
    plt.savefig("italy_cases.jpg", dpi=200)
    plt.show()

plot_country_cases("Italy")

# %%
import os
os.chdir(r'C:\Users\gcris\Documents\MEGA\MEGAsync\Programming\Python\Learning topics\Application_PysimpleGUI_Seaborn')
os.getcwd()
# Out:
# 'C:\\Users\\gcris\\Documents\\MEGA\\MEGAsync\\Programming\\Python\\Learning topics\\Application_PysimpleGUI_Seaborn'
